# %% [markdown]
# <a href="https://colab.research.google.com/github/Baladityakola/FMML_Projects_and_Labs/blob/main/Module_7_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Module 7 Project: Movie Recommendation Engine

# %% [markdown]
# `Module Coordinator: Ganesh Chandan`

# %% [markdown]
# In this module, we will try to create a Movie Recommendation System using different unsupervised learning techniques.

# %%
# dataset download

# !wget https://files.grouplens.org/datasets/movielens/ml-100k.zip
# !wget https://files.grouplens.org/datasets/movielens/ml-latest-small.zip
# !unzip ml-latest-small.zip
# Out:
# --2024-02-27 02:10:07--  https://files.grouplens.org/datasets/movielens/ml-latest-small.zip
# Resolving files.grouplens.org (files.grouplens.org)... 128.101.65.152
# Connecting to files.grouplens.org (files.grouplens.org)|128.101.65.152|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 978202 (955K) [application/zip]
# Saving to: ‘ml-latest-small.zip’
#
# ml-latest-small.zip 100%[===================>] 955.28K  4.62MB/s    in 0.2s
#
# 2024-02-27 02:10:07 (4.62 MB/s) - ‘ml-latest-small.zip’ saved [978202/978202]
#
# Archive:  ml-latest-small.zip
#    creating: ml-latest-small/
#   inflating: ml-latest-small/links.csv
#   inflating: ml-latest-small/tags.csv
#   inflating: ml-latest-small/ratings.csv
#   inflating: ml-latest-small/README.txt
#   inflating: ml-latest-small/movies.csv

# %% [markdown]
# ## Clustering based recommendation

# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.sparse import csr_matrix
from mpl_toolkits.axes_grid1 import make_axes_locatable
from sklearn.cluster import KMeans
from sklearn.metrics import mean_squared_error
import itertools
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
# Import the Movies dataset
movies = pd.read_csv('ml-latest-small/movies.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Import the ratings dataset
ratings = pd.read_csv('ml-latest-small/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
# Print the number of records and the total number of movies
print('The dataset contains: ', len(ratings), ' ratings of ', len(movies), ' movies.')
# Out:
# The dataset contains:  100836  ratings of  9742  movies.

# %% [markdown]
# ### Romance versus Science Fiction
#
# We will start by considering a subset of users and discovering what are their favourite genre. We will do this by defining a function that will calculate each user’s average rating for all science fiction and romance movies.

# %%
# Function to get the genre ratings
def get_genre_ratings(ratings, movies, genres, column_names):
    genre_ratings = pd.DataFrame()
    for genre in genres:
        genre_movies = movies[movies['genres'].str.contains(genre) ]
        avg_genre_votes_per_user = ratings[ratings['movieId'].isin(genre_movies['movieId'])].loc[:, ['userId', 'rating']].groupby(['userId'])['rating'].mean().round(2)

        genre_ratings = pd.concat([genre_ratings, avg_genre_votes_per_user], axis=1)

    genre_ratings.columns = column_names
    return genre_ratings# Calculate the average rating of romance and scifi movies
genre_ratings = get_genre_ratings(ratings, movies, ['Romance', 'Sci-Fi'], ['avg_romance_rating', 'avg_scifi_rating'])
genre_ratings.head()
# Out:
#    avg_romance_rating  avg_scifi_rating
# 1                4.31              4.22
# 2                4.50              3.88
# 3                0.50              4.20
# 4                3.38              2.83
# 5                3.09              2.50

# %% [markdown]
# In order to have a more delimited subset of people to study, we are going to bias our grouping to only get ratings from those users that like either romance or science fiction movies.

# %%
# Function to get the biased dataset
def bias_genre_rating_dataset(genre_ratings, score_limit_1, score_limit_2):
    biased_dataset =    genre_ratings[((genre_ratings['avg_romance_rating'] < score_limit_1 - 0.2) & (genre_ratings['avg_scifi_rating'] > score_limit_2)) | ((genre_ratings['avg_scifi_rating'] < score_limit_1) & (genre_ratings['avg_romance_rating'] > score_limit_2))]
    biased_dataset = pd.concat([biased_dataset[:300], genre_ratings[:2]])
    biased_dataset = pd.DataFrame(biased_dataset.to_records())
    return biased_dataset

# Bias the dataset
biased_dataset = bias_genre_rating_dataset(genre_ratings, 3.2, 2.5)

# Printing the resulting number of records & the head of the dataset
print( "Number of records: ", len(biased_dataset))
biased_dataset.head()
# Out:
# Number of records:  162
#    index  avg_romance_rating  avg_scifi_rating
# 0      3                0.50              4.20
# 1      4                3.38              2.83
# 2      5                3.09              2.50
# 3      7                2.65              3.15
# 4      9                3.17              3.00

# %%
# Defining the scatterplot drawing function
def draw_scatterplot(x_data, x_label, y_data, y_label):
    fig = plt.figure(figsize=(8,8))
    ax = fig.add_subplot(111)
    plt.xlim(0, 5)
    plt.ylim(0, 5)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.scatter(x_data, y_data, s=30)

# Plot the scatterplot
draw_scatterplot(biased_dataset['avg_scifi_rating'],'Avg scifi rating', biased_dataset['avg_romance_rating'], 'Avg romance rating')

# %%
# Let's turn our dataset into a list
X = biased_dataset[['avg_scifi_rating','avg_romance_rating']].values

# Import KMeans
from sklearn.cluster import KMeans

# Create an instance of KMeans to find two clusters
kmeans_1 = KMeans(n_clusters=2)

# Use fit_predict to cluster the dataset
predictions = kmeans_1.fit_predict(X)

# Defining the cluster plotting function
def draw_clusters(biased_dataset, predictions, cmap='viridis'):
    fig = plt.figure(figsize=(8,8))
    ax = fig.add_subplot(111)
    plt.xlim(0, 5)
    plt.ylim(0, 5)
    ax.set_xlabel('Avg scifi rating')
    ax.set_ylabel('Avg romance rating')
    clustered = pd.concat([biased_dataset.reset_index(), pd.DataFrame({'group':predictions})], axis=1)
    plt.scatter(clustered['avg_scifi_rating'], clustered['avg_romance_rating'], c=clustered['group'], s=20, cmap=cmap)

# Plot
draw_clusters(biased_dataset, predictions)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Create an instance of KMeans to find three clusters
kmeans_2 = KMeans(n_clusters=3)
# Use fit_predict to cluster the dataset
predictions_2 = kmeans_2.fit_predict(X)
# Plot
draw_clusters(biased_dataset, predictions_2)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# It is evident now that the science-fiction rating has started to come into play:
#
#     People who like sci-fi and romance modeately belong to the green group.
#     People who like scifi but not romance belong to the yello group.
#     People who like romance but not sci-fi belong to the purple group.

# %% [markdown]
# Finding optimal clusters using silhouette score

# %%
# Selecting our dataset to study
df = biased_dataset[['avg_scifi_rating','avg_romance_rating']]

# Choose the range of k values to test.
# We added a stride of 5 to improve performance. We don't need to calculate the error for every k value
possible_k_values = range(2, len(X)+1, 5)

# Define function to calculate the clustering errors
def clustering_errors(k, data):
    kmeans = KMeans(n_clusters=k).fit(data)
    predictions = kmeans.predict(data)
    #cluster_centers = kmeans.cluster_centers_
    # errors = [mean_squared_error(row, cluster_centers[cluster]) for row, cluster in zip(data.values, predictions)]
    # return sum(errors)
    silhouette_avg = silhouette_score(data, predictions)
    return silhouette_avg

# Calculate error values for all k values we're interested in
errors_per_k = [clustering_errors(k, X) for k in possible_k_values]

# Plot the each value of K vs. the silhouette score at that value
fig, ax = plt.subplots(figsize=(16, 6))
plt.plot(possible_k_values, errors_per_k)

# Ticks and grid
xticks = np.arange(min(possible_k_values), max(possible_k_values)+1, 5.0)
ax.set_xticks(xticks, minor=False)
ax.set_xticks(xticks, minor=True)
ax.xaxis.grid(True, which='both')
yticks = np.arange(round(min(errors_per_k), 2), max(errors_per_k), .05)
ax.set_yticks(yticks, minor=False)
ax.set_yticks(yticks, minor=True)
ax.yaxis.grid(True, which='both')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-11-ea56d5ac5a15>:10: ConvergenceWarning: Number of distinct clusters (157) found smaller than n_clusters (162). Possibly due to duplicate points in X.
#   kmeans = KMeans(n_clusters=k).fit(data)

# %% [markdown]
# We will chose the K = 7 as it is the one that yields the best score and will be easier to visualize.

# %%
# Create an instance of KMeans to find seven clusters
kmeans_4 = KMeans(n_clusters=7)
# Use fit_predict to cluster the dataset
predictions_4 = kmeans_4.fit_predict(X)
# Plot
draw_clusters(biased_dataset, predictions_4, cmap='Accent')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# Up to now, we have only analyzed romance and science-fiction movies. Let us see what happens when adding other genre to our analysis by adding Action movies.

# %%
# Select our biased dataset and add action genre
biased_dataset_3_genres = get_genre_ratings(ratings, movies, ['Romance','Sci-Fi', 'Action'],
['avg_romance_rating', 'avg_scifi_rating', 'avg_action_rating'])
# Drop null values
biased_dataset_3_genres = bias_genre_rating_dataset(biased_dataset_3_genres, 3.2, 2.5).dropna()
# Print the number of records and the head of our dataset
print( "Number of records: ", len(biased_dataset_3_genres))
biased_dataset_3_genres.head()
# Out:
# Number of records:  161
#    index  avg_romance_rating  avg_scifi_rating  avg_action_rating
# 0      3                0.50              4.20               3.57
# 1      4                3.38              2.83               3.32
# 2      5                3.09              2.50               3.11
# 3      7                2.65              3.15               3.26
# 4      9                3.17              3.00               3.12

# %%
# Turn dataset into a list
X_with_action = biased_dataset_3_genres[['avg_scifi_rating','avg_romance_rating','avg_action_rating']].values# Create an instance of KMeans to find seven clusters
kmeans_5 = KMeans(n_clusters=7)
# Use fit_predict to cluster the dataset
predictions_5 = kmeans_5.fit_predict(X_with_action)
# Define 3d plotting function
def draw_clusters_3d(biased_dataset_3, predictions):
    fig = plt.figure(figsize=(8,8))
    ax = fig.add_subplot(111)
    plt.xlim(0, 5)
    plt.ylim(0, 5)
    ax.set_xlabel('Avg scifi rating')
    ax.set_ylabel('Avg romance rating')
    clustered = pd.concat([biased_dataset_3.reset_index(), pd.DataFrame({'group':predictions})], axis=1)
    colors = itertools.cycle(plt.rcParams["axes.prop_cycle"].by_key()["color"])
    for g in clustered.group.unique():
        color = next(colors)
        for index, point in clustered[clustered.group == g].iterrows():
            if point['avg_action_rating'].astype(float) > 3:
                size = 50
            else:
                size = 15
            plt.scatter(point['avg_scifi_rating'],
                        point['avg_romance_rating'],
                        s=size,
                        color=color)# Plot
draw_clusters_3d(biased_dataset_3_genres, predictions_5)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# The size of the dots represent the ratings of the action movies.

# %% [markdown]
# # Exercise 1
#
# ## Instead of choosing a n_clusters as 7, play around with different k
# ## Find the optimal no of clusters with 3 genre_ratings data we just created using silhouette score method

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')

genre_ratings_imputed = imputer.fit_transform(genre_ratings)

silhouette_scores = []

for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(genre_ratings_imputed)
    silhouette_avg = silhouette_score(genre_ratings_imputed, kmeans.labels_)
    silhouette_scores.append((k, silhouette_avg))

best_k, best_silhouette_score = max(silhouette_scores, key=lambda x: x[1])

print(f"The optimal number of clusters is: {best_k} with a silhouette score of {best_silhouette_score}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# The optimal number of clusters is: 2 with a silhouette score of 0.402772563719914

# %% [markdown]
# ### Taking users into consideration

# %% [markdown]
# Once we have seen and understood how the K-Means algorithm group the users by their movie genre preferences, we are going to take a bigger picture of the dataset and explore how users rate individual movies.
#
# To do so, we will subset the dataset by ‘userid’ vs ‘user rating’ as follows.

# %%
# Merge the two tables then pivot so we have Users X Movies dataframe
ratings_title = pd.merge(ratings, movies[['movieId', 'title']], on='movieId' )
user_movie_ratings = pd.pivot_table(ratings_title, index='userId', columns= 'title', values='rating')

# Print he number of dimensions and a subset of the dataset
print('dataset dimensions: ', user_movie_ratings.shape, '\n\nSubset example:')
user_movie_ratings.iloc[:6, :10]
# Out:
# dataset dimensions:  (610, 9719)
#
# Subset example:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
# 6              NaN                                      NaN
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
# 5                          NaN                  NaN
# 6                          NaN                  NaN
#
# title   'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userId
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
# 6                             NaN                              NaN
#
# title   'burbs, The (1989)  'night Mother (1986)  (500) Days of Summer (2009)  \
# userId
# 1                      NaN                   NaN                          NaN
# 2                      NaN                   NaN                          NaN
# 3                      NaN                   NaN                          NaN
# 4                      NaN                   NaN                          NaN
# 5                      NaN                   NaN                          NaN
# 6                      NaN                   NaN                          NaN
#
# title   *batteries not included (1987)
# userId
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN

# %%
# Define Function to get the most rated movies
def get_most_rated_movies(user_movie_ratings, max_number_of_movies):
    # 1- Count
    user_movie_ratings = user_movie_ratings.append(user_movie_ratings.count(), ignore_index=True)
    # 2- sort
    user_movie_ratings_sorted = user_movie_ratings.sort_values(len(user_movie_ratings)-1, axis=1, ascending=False)
    user_movie_ratings_sorted = user_movie_ratings_sorted.drop(user_movie_ratings_sorted.tail(1).index)
    # 3- slice
    most_rated_movies = user_movie_ratings_sorted.iloc[:, :max_number_of_movies]
    return most_rated_movies

# Define function to get the user who rate a movie the most
def get_users_who_rate_the_most(most_rated_movies, n_users):
    most_rated_movies['num_ratings'] = - most_rated_movies.isnull().sum(axis=1)
    most_rated_movies = most_rated_movies.sort_values(by=['num_ratings'], ascending=False)
    most_rated_movies = most_rated_movies.iloc[:n_users, :]
    most_rated_movies = most_rated_movies.drop('num_ratings', axis=1)
    return most_rated_movies

# Define the sorting by rating function
def sort_by_rating_density(user_movie_ratings, n_movies, n_users):
    most_rated_movies = get_most_rated_movies(user_movie_ratings, n_movies)
    most_rated_movies = get_users_who_rate_the_most(most_rated_movies, n_users)
    return most_rated_movies

# choose the number of movies and users and sort
n_movies = 30
n_users = 18
most_rated_movies_users_selection = sort_by_rating_density(user_movie_ratings, n_movies, n_users)

# Print the result
# print(most_rated_movies_users_selection)
print('dataset dimensions: ', most_rated_movies_users_selection.shape)
print(most_rated_movies_users_selection.head())
# Out:
# dataset dimensions:  (18, 30)
# title  Forrest Gump (1994)  Shawshank Redemption, The (1994)  \
# 413                    5.0                               5.0
# 589                    5.0                               4.5
# 473                    3.0                               5.0
# 479                    5.0                               5.0
# 67                     3.5                               3.0
#
# title  Pulp Fiction (1994)  Silence of the Lambs, The (1991)  \
# 413                    5.0                               4.0
# 589                    4.5                               3.5
# 473                    4.0                               4.5
# 479                    4.0                               4.5
# 67                     2.0                               3.5
#
# title  Matrix, The (1999)  Star Wars: Episode IV - A New Hope (1977)  \
# 413                   5.0                                        5.0
# 589                   4.0                                        5.0
# 473                   4.5                                        4.0
# 479                   5.0                                        4.5
# 67                    4.5                                        5.0
#
# title  Jurassic Park (1993)  Braveheart (1995)  \
# 413                     4.0                5.0
# 589                     4.0                4.0
# 473                     4.5                3.0
# 479                     5.0                5.0
# 67                      3.5                2.5
#
# title  Terminator 2: Judgment Day (1991)  Schindler's List (1993)  ...  \
# 413                                  5.0                      4.0  ...
# 589                                  4.5                      5.0  ...
# 473                                  4.0                      5.0  ...
# 479                                  4.5                      5.0  ...
# 67                                   3.5                      4.0  ...
#
# title  Star Wars: Episode VI - Return of the Jedi (1983)  \
# 413                                                  5.0
# 589                                                  4.5
# 473                                                  4.0
# 479                                                  3.5
# 67                                                   5.0
#
# title  Godfather, The (1972)  Fugitive, The (1993)  Batman (1989)  \
# 413                      5.0                   5.0            4.0
# 589                      5.0                   4.0            3.5
# 473                      5.0                   5.0            4.0
# 479                      5.0                   3.5            4.5
# 67                       4.0                   4.5            4.0
#
# title  Saving Private Ryan (1998)  \
# 413                           5.0
# 589                           4.0
# 473                           3.0
# 479                           4.5
# 67                            4.0
#
# title  Lord of the Rings: The Two Towers, The (2002)  \
# 413                                              5.0
# 589                                              5.0
# 473                                              5.0
# 479                                              4.5
# 67                                               4.0
#
# title  Lord of the Rings: The Return of the King, The (2003)  Aladdin (1992)  \
# 413                                                  4.0                 4.0
# 589                                                  4.5                 4.0
# 473                                                  5.0                 4.0
# 479                                                  4.0                 4.0
# 67                                                   4.5                 3.5
#
# title  Fargo (1996)  Sixth Sense, The (1999)
# 413             5.0                      3.0
# 589             4.0                      3.5
# 473             4.0                      5.0
# 479             4.0                      4.0
# 67              2.5                      2.5
#
# [5 rows x 30 columns]
# <ipython-input-17-0b2c7ceec495>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   user_movie_ratings = user_movie_ratings.append(user_movie_ratings.count(), ignore_index=True)

# %%
# Define the plotting heatmap function
def draw_movies_heatmap(most_rated_movies_users_selection, axis_labels=True):

    fig = plt.figure(figsize=(15,4))
    ax = plt.gca()

    # Draw heatmap
    heatmap = ax.imshow(most_rated_movies_users_selection,  interpolation='nearest', vmin=0, vmax=5, aspect='auto')
    if axis_labels:
        ax.set_yticks(np.arange(most_rated_movies_users_selection.shape[0]) , minor=False)
        ax.set_xticks(np.arange(most_rated_movies_users_selection.shape[1]) , minor=False)
        ax.invert_yaxis()
        ax.xaxis.tick_top()
        labels = most_rated_movies_users_selection.columns.str[:40]
        ax.set_xticklabels(labels, minor=False)
        ax.set_yticklabels(most_rated_movies_users_selection.index, minor=False)
        plt.setp(ax.get_xticklabels(), rotation=90)
    else:
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    ax.grid(False)
    ax.set_ylabel('User id')# Separate heatmap from color bar
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)# Color bar
    cbar = fig.colorbar(heatmap, ticks=[5, 4, 3, 2, 1, 0], cax=cax)
    cbar.ax.set_yticklabels(['5 stars', '4 stars','3 stars','2 stars','1 stars','0 stars'])
    plt.show()# Print the heatmap
draw_movies_heatmap(most_rated_movies_users_selection)

# %%
# Pivot the dataset and choose the first 1000 movies
user_movie_ratings =  pd.pivot_table(ratings_title, index='userId', columns= 'title', values='rating')
most_rated_movies_1k = get_most_rated_movies(user_movie_ratings, 1000).replace(np.nan, 0)
# Out:
# <ipython-input-17-0b2c7ceec495>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   user_movie_ratings = user_movie_ratings.append(user_movie_ratings.count(), ignore_index=True)

# %%
from scipy import sparse

# Conversion to sparse csr matrix
sparse_ratings = sparse.csr_matrix(most_rated_movies_1k.values)

# %% [markdown]
# ### Large Scale Clustering

# %%
# 20 clusters
predictions = KMeans(n_clusters=20, algorithm='full').fit_predict(sparse_ratings)
# Select the mas number of users and movies heatmap cluster
# Cluster and print some of them
clustered = pd.concat([get_most_rated_movies(user_movie_ratings, 1000).reset_index(), pd.DataFrame({'group':predictions})], axis=1)
# draw_movie_clusters(clustered, max_users, max_movies)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1366: FutureWarning: algorithm='full' is deprecated, it will be removed in 1.3. Using 'lloyd' instead.
#   warnings.warn(
# <ipython-input-17-0b2c7ceec495>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   user_movie_ratings = user_movie_ratings.append(user_movie_ratings.count(), ignore_index=True)

# %% [markdown]
# ### Predictions and Recommendation

# %%
# Pick a cluster ID from the clusters above
cluster_number = 11
# Let's filter to only see the region of the dataset with the most number of values
n_users = 75
n_movies = 300
cluster = clustered[clustered.group == cluster_number].drop(['index', 'group'], axis=1)
print(cluster)
# Sort and print the cluster
cluster = sort_by_rating_density(cluster, n_movies, n_users)
draw_movies_heatmap(cluster, axis_labels=False)
# Out:
# <ipython-input-17-0b2c7ceec495>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   user_movie_ratings = user_movie_ratings.append(user_movie_ratings.count(), ignore_index=True)
#      Forrest Gump (1994)  Shawshank Redemption, The (1994)  \
# 6                    5.0                               NaN
# 9                    3.5                               NaN
# 24                   NaN                               NaN
# 29                   NaN                               5.0
# 51                   5.0                               5.0
# ..                   ...                               ...
# 580                  4.5                               5.0
# 581                  NaN                               NaN
# 585                  NaN                               5.0
# 600                  NaN                               5.0
# 604                  3.0                               NaN
#
#      Pulp Fiction (1994)  Silence of the Lambs, The (1991)  \
# 6                    NaN                               5.0
# 9                    1.0                               NaN
# 24                   NaN                               NaN
# 29                   NaN                               NaN
# 51                   NaN                               NaN
# ..                   ...                               ...
# 580                  NaN                               NaN
# 581                  NaN                               4.0
# 585                  NaN                               NaN
# 600                  NaN                               NaN
# 604                  2.0                               NaN
#
#      Matrix, The (1999)  Star Wars: Episode IV - A New Hope (1977)  \
# 6                   NaN                                        5.0
# 9                   0.5                                        NaN
# 24                  5.0                                        5.0
# 29                  5.0                                        5.0
# 51                  5.0                                        4.0
# ..                  ...                                        ...
# 580                 3.5                                        NaN
# 581                 5.0                                        4.0
# 585                 5.0                                        4.5
# 600                 5.0                                        NaN
# 604                 NaN                                        5.0
#
#      Jurassic Park (1993)  Braveheart (1995)  \
# 6                     5.0                NaN
# 9                     NaN                NaN
# 24                    NaN                NaN
# 29                    NaN                5.0
# 51                    NaN                NaN
# ..                    ...                ...
# 580                   NaN                NaN
# 581                   NaN                NaN
# 585                   NaN                5.0
# 600                   NaN                NaN
# 604                   3.0                3.0
#
#      Terminator 2: Judgment Day (1991)  Schindler's List (1993)  ...  \
# 6                                  2.5                      NaN  ...
# 9                                  NaN                      NaN  ...
# 24                                 NaN                      5.0  ...
# 29                                 3.5                      NaN  ...
# 51                                 NaN                      NaN  ...
# ..                                 ...                      ...  ...
# 580                                NaN                      5.0  ...
# 581                                NaN                      NaN  ...
# 585                                5.0                      2.5  ...
# 600                                NaN                      5.0  ...
# 604                                3.5                      NaN  ...
#
#      Scary Movie 2 (2001)  About Schmidt (2002)  21 Jump Street (2012)  \
# 6                     NaN                   NaN                    NaN
# 9                     NaN                   NaN                    NaN
# 24                    NaN                   NaN                    NaN
# 29                    NaN                   NaN                    5.0
# 51                    NaN                   NaN                    NaN
# ..                    ...                   ...                    ...
# 580                   NaN                   NaN                    NaN
# 581                   NaN                   NaN                    NaN
# 585                   NaN                   NaN                    NaN
# 600                   NaN                   NaN                    NaN
# 604                   NaN                   NaN                    NaN
#
#      Cider House Rules, The (1999)  Death Proof (2007)  Moonraker (1979)  \
# 6                              NaN                 NaN               NaN
# 9                              NaN                 NaN               NaN
# 24                             NaN                 NaN               NaN
# 29                             NaN                 NaN               NaN
# 51                             NaN                 NaN               NaN
# ..                             ...                 ...               ...
# 580                            NaN                 NaN               NaN
# 581                            NaN                 NaN               NaN
# 585                            NaN                 NaN               NaN
# 600                            NaN                 NaN               NaN
# 604                            NaN                 NaN               NaN
#
#      Virgin Suicides, The (1999)  ¡Three Amigos! (1986)  \
# 6                            NaN                    NaN
# 9                            NaN                    NaN
# 24                           NaN                    NaN
# 29                           NaN                    NaN
# 51                           NaN                    NaN
# ..                           ...                    ...
# 580                          NaN                    NaN
# 581                          NaN                    NaN
# 585                          NaN                    NaN
# 600                          NaN                    NaN
# 604                          NaN                    NaN
#
#      Waking Ned Devine (a.k.a. Waking Ned) (1998)  Jacob's Ladder (1990)
# 6                                             NaN                    NaN
# 9                                             NaN                    NaN
# 24                                            NaN                    NaN
# 29                                            NaN                    NaN
# 51                                            NaN                    NaN
# ..                                            ...                    ...
# 580                                           NaN                    NaN
# 581                                           NaN                    NaN
# 585                                           NaN                    NaN
# 600                                           NaN                    NaN
# 604                                           NaN                    NaN
#
# [63 rows x 1000 columns]

# %%
# Fill in the name of the column/movie. e.g. 'Forrest Gump (1994)'
movie_name = "Matrix, The (1999)"
cluster[movie_name].mean()
# Out:
# 4.353658536585366

# %%
# The average rating of 20 movies as rated by the users in the cluster
cluster.mean().head(20)
# Out:
# Lord of the Rings: The Fellowship of the Ring, The (2001)        4.190000
# Lord of the Rings: The Return of the King, The (2003)            4.180000
# Lord of the Rings: The Two Towers, The (2002)                    4.227273
# Matrix, The (1999)                                               4.353659
# Inception (2010)                                                 3.975000
# Dark Knight, The (2008)                                          4.416667
# Forrest Gump (1994)                                              4.220588
# Up (2009)                                                        4.117647
# Shawshank Redemption, The (1994)                                 4.426471
# Star Wars: Episode IV - A New Hope (1977)                        4.075758
# WALL·E (2008)                                                    4.266667
# Pirates of the Caribbean: The Curse of the Black Pearl (2003)    4.083333
# Fight Club (1999)                                                4.100000
# Shrek (2001)                                                     3.965517
# Iron Man (2008)                                                  4.137931
# Avatar (2009)                                                    3.767857
# Batman Begins (2005)                                             3.903846
# Monsters, Inc. (2001)                                            4.096154
# Incredibles, The (2004)                                          4.080000
# Avengers, The (2012)                                             4.140000
# dtype: float64

# %%
cluster
# Out:
#     Lord of the Rings: The Fellowship of the Ring, The (2001)  \
# 46                                                5.0
# 13                                                5.0
# 15                                                4.0
# 31                                                3.5
# 7                                                 NaN
# ..                                                ...
# 38                                                5.0
# 20                                                4.0
# 56                                                4.5
# 50                                                NaN
# 2                                                 5.0
#
#     Lord of the Rings: The Return of the King, The (2003)  \
# 46                                                5.0
# 13                                                5.0
# 15                                                4.0
# 31                                                3.0
# 7                                                 NaN
# ..                                                ...
# 38                                                5.0
# 20                                                4.0
# 56                                                4.0
# 50                                                NaN
# 2                                                 5.0
#
#     Lord of the Rings: The Two Towers, The (2002)  Matrix, The (1999)  \
# 46                                            5.0                 4.5
# 13                                            4.5                 4.0
# 15                                            4.0                 NaN
# 31                                            3.0                 NaN
# 7                                             NaN                 NaN
# ..                                            ...                 ...
# 38                                            5.0                 5.0
# 20                                            4.0                 4.0
# 56                                            4.0                 NaN
# 50                                            NaN                 NaN
# 2                                             5.0                 5.0
#
#     Inception (2010)  Dark Knight, The (2008)  Forrest Gump (1994)  Up (2009)  \
# 46               NaN                      3.5                  NaN        NaN
# 13               4.0                      4.5                  4.0        5.0
# 15               2.0                      3.5                  NaN        2.5
# 31               1.5                      3.5                  4.5        3.0
# 7                2.5                      4.5                  NaN        4.0
# ..               ...                      ...                  ...        ...
# 38               NaN                      5.0                  NaN        3.0
# 20               4.5                      5.0                  4.0        4.5
# 56               NaN                      NaN                  NaN        NaN
# 50               5.0                      5.0                  5.0        NaN
# 2                5.0                      5.0                  NaN        5.0
#
#     Shawshank Redemption, The (1994)  \
# 46                               NaN
# 13                               4.5
# 15                               NaN
# 31                               4.5
# 7                                NaN
# ..                               ...
# 38                               NaN
# 20                               4.0
# 56                               NaN
# 50                               5.0
# 2                                NaN
#
#     Star Wars: Episode IV - A New Hope (1977)  ...  Gone in 60 Seconds (2000)  \
# 46                                        5.0  ...                        4.0
# 13                                        NaN  ...                        NaN
# 15                                        4.0  ...                        1.5
# 31                                        3.0  ...                        NaN
# 7                                         2.0  ...                        NaN
# ..                                        ...  ...                        ...
# 38                                        4.0  ...                        NaN
# 20                                        NaN  ...                        NaN
# 56                                        NaN  ...                        NaN
# 50                                        5.0  ...                        NaN
# 2                                         5.0  ...                        NaN
#
#     Man on Fire (2004)  Step Brothers (2008)  Inside Man (2006)  \
# 46                 NaN                   NaN                NaN
# 13                 NaN                   NaN                NaN
# 15                 2.0                   NaN                2.0
# 31                 NaN                   3.5                NaN
# 7                  NaN                   4.5                NaN
# ..                 ...                   ...                ...
# 38                 NaN                   NaN                NaN
# 20                 NaN                   NaN                NaN
# 56                 NaN                   NaN                NaN
# 50                 NaN                   NaN                NaN
# 2                  NaN                   NaN                NaN
#
#     Bowling for Columbine (2002)  Terminator 3: Rise of the Machines (2003)  \
# 46                           NaN                                        NaN
# 13                           NaN                                        NaN
# 15                           NaN                                        2.5
# 31                           0.5                                        NaN
# 7                            NaN                                        NaN
# ..                           ...                                        ...
# 38                           NaN                                        NaN
# 20                           NaN                                        NaN
# 56                           NaN                                        NaN
# 50                           NaN                                        NaN
# 2                            NaN                                        NaN
#
#     Wild Wild West (1999)  What Women Want (2000)  \
# 46                    NaN                     NaN
# 13                    3.0                     NaN
# 15                    NaN                     NaN
# 31                    NaN                     NaN
# 7                     NaN                     NaN
# ..                    ...                     ...
# 38                    NaN                     NaN
# 20                    NaN                     NaN
# 56                    NaN                     NaN
# 50                    NaN                     NaN
# 2                     NaN                     NaN
#
#     Wallace & Gromit in The Curse of the Were-Rabbit (2005)  Superbad (2007)
# 46                                                NaN                    NaN
# 13                                                NaN                    NaN
# 15                                                NaN                    NaN
# 31                                                NaN                    3.5
# 7                                                 NaN                    1.5
# ..                                                ...                    ...
# 38                                                NaN                    NaN
# 20                                                NaN                    NaN
# 56                                                NaN                    NaN
# 50                                                NaN                    NaN
# 2                                                 NaN                    NaN
#
# [63 rows x 300 columns]

# %%
# Predict for a specific user

# Pick a user ID from the dataset
user_id = 7
# Get all this user's ratings
user_2_ratings  = cluster.loc[user_id, :]
# Which movies did they not rate?
user_2_unrated_movies =  user_2_ratings[user_2_ratings.isnull()]
# What are the ratings of these movies the user did not rate?
avg_ratings = pd.concat([user_2_unrated_movies, cluster.mean()], axis=1, join='inner').loc[:,0]
# Let's sort by rating so the highest rated movies are presented first
avg_ratings.sort_values(ascending=False)[:20]
# Out:
# Wallace & Gromit in The Curse of the Were-Rabbit (2005)                                           4.625000
# Into the Wild (2007)                                                                              4.625000
# Back to the Future Part II (1989)                                                                 4.583333
# Serenity (2005)                                                                                   4.562500
# Harry Potter and the Deathly Hallows: Part 2 (2011)                                               4.500000
# Contact (1997)                                                                                    4.500000
# Snatch (2000)                                                                                     4.500000
# Green Mile, The (1999)                                                                            4.500000
# Shawshank Redemption, The (1994)                                                                  4.426471
# Limitless (2011)                                                                                  4.416667
# Ex Machina (2015)                                                                                 4.400000
# Good Will Hunting (1997)                                                                          4.392857
# Harry Potter and the Deathly Hallows: Part 1 (2010)                                               4.384615
# Intouchables (2011)                                                                               4.357143
# Matrix, The (1999)                                                                                4.353659
# Illusionist, The (2006)                                                                           4.350000
# Harry Potter and the Goblet of Fire (2005)                                                        4.343750
# Back to the Future (1985)                                                                         4.321429
# Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone) (2001)    4.315789
# Ant-Man (2015)                                                                                    4.312500
# Name: 0, dtype: float64

# %% [markdown]
# ## Using Collaborative Filtering (With fast.ai)

# %%
! [ -e /content ] && pip install -Uqq fastai

# %%
from fastai.tabular.all import *
from fastai.collab import *

# %% [markdown]
# ### Training a model

# %% [markdown]
# For this, we will use the [Movielens 100k data dataset](https://grouplens.org/datasets/movielens/100k/). We can download it easily and decompress it with the following function:

# %%
path = untar_data(URLs.ML_100k)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4931584' class='' max='4924029' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.15% [4931584/4924029 00:00&lt;00:00]
#     </div>

# %% [markdown]
# The main table is in `u.data`. Since it's not a proper csv, we have to specify a few things while opening it: the tab delimiter, the columns we want to keep and their names.

# %%
ratings = pd.read_csv(path/'u.data', delimiter='\t', header=None,
                      usecols=(0,1,2), names=['user','movie','rating'])
ratings.head()
# Out:
#    user  movie  rating
# 0   196    242       3
# 1   186    302       3
# 2    22    377       1
# 3   244     51       2
# 4   166    346       1

# %% [markdown]
# Movie ids are not ideal to look at things, so we load the corresponding movie id to the title that is in the table `u.item`:

# %%
movies = pd.read_csv(path/'u.item',  delimiter='|', encoding='latin-1',
                     usecols=(0,1), names=('movie','title'), header=None)
movies.head()
# Out:
#    movie              title
# 0      1   Toy Story (1995)
# 1      2   GoldenEye (1995)
# 2      3  Four Rooms (1995)
# 3      4  Get Shorty (1995)
# 4      5     Copycat (1995)

# %% [markdown]
# Next we merge it to our ratings table:

# %%
ratings = ratings.merge(movies)
ratings.head()
# Out:
#    user  movie  rating         title
# 0   196    242       3  Kolya (1996)
# 1    63    242       3  Kolya (1996)
# 2   226    242       5  Kolya (1996)
# 3   154    242       3  Kolya (1996)
# 4   306    242       5  Kolya (1996)

# %% [markdown]
# We can then build a `DataLoaders` object from this table. By default, it takes the first column for user, the second column for the item (here our movies) and the third column for the ratings. We need to change the value of `item_name` in our case, to use the titles instead of the ids:

# %%
dls = CollabDataLoaders.from_df(ratings, item_name='title', bs=64)

# %% [markdown]
# In all applications, when the data has been assembled in a `DataLoaders`, you can have a look at it with the `show_batch` method:

# %%
dls.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user</th>
#       <th>title</th>
#       <th>rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>829</td>
#       <td>Before the Rain (Pred dozhdot) (1994)</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>292</td>
#       <td>Dead Man Walking (1995)</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>256</td>
#       <td>True Lies (1994)</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>422</td>
#       <td>Star Wars (1977)</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>341</td>
#       <td>Gang Related (1997)</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>181</td>
#       <td>Jerry Maguire (1996)</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>703</td>
#       <td>Birdcage, The (1996)</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>927</td>
#       <td>High School High (1996)</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>881</td>
#       <td>Godfather, The (1972)</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>886</td>
#       <td>Getaway, The (1994)</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# fastai can create and train a collaborative filtering model by using `collab_learner`:

# %%
learn = collab_learner(dls, n_factors=50, y_range=(0, 5.5))

# %% [markdown]
# It uses a simple dot product model with 50 latent factors. To train it using the 1cycle policy, we just run this command:

# %%
learn.fit_one_cycle(5, 5e-3, wd=0.1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.964968</td>
#       <td>0.950833</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.891307</td>
#       <td>0.867986</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.748408</td>
#       <td>0.827910</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.599214</td>
#       <td>0.815615</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.495984</td>
#       <td>0.816243</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Here's [some benchmarks](https://www.librec.net/release/v1.3/example.html) on the same dataset for the popular Librec system for collaborative filtering. They show best results based on RMSE of 0.91 (scroll down to the 100k dataset), which corresponds to an MSE of `0.91**2 = 0.83`. So in less than a minute, we got pretty good results!

# %% [markdown]
# ### Interpretation

# %% [markdown]
# Let's analyze the results of our previous model. We will keep the 1000 most rated movies for this:

# %%
g = ratings.groupby('title')['rating'].count()
top_movies = g.sort_values(ascending=False).index.values[:1000]
top_movies[:10]
# Out:
# array(['Star Wars (1977)', 'Contact (1997)', 'Fargo (1996)',
#        'Return of the Jedi (1983)', 'Liar Liar (1997)',
#        'English Patient, The (1996)', 'Scream (1996)', 'Toy Story (1995)',
#        'Air Force One (1997)', 'Independence Day (ID4) (1996)'],
#       dtype=object)

# %% [markdown]
# ### Movie bias

# %% [markdown]
# Our model has learned one bias per movie, a unique number independent of users that can be interpreted as the intrinsic "value" of the movie. We can grab the bias of each movie in our `top_movies` list with the following command:

# %%
movie_bias = learn.model.bias(top_movies, is_item=True)
movie_bias.shape
# Out:
# torch.Size([1000])

# %% [markdown]
# Let's compare those biases with the average ratings:

# %%
mean_ratings = ratings.groupby('title')['rating'].mean()
movie_ratings = [(b, i, mean_ratings.loc[i]) for i,b in zip(top_movies,movie_bias)]

# %% [markdown]
# Now let's have a look at the movies with the worst bias:

# %%
item0 = lambda o:o[0]
sorted(movie_ratings, key=item0)[:15]
# Out:
# [(tensor(-0.3144), 'Crow: City of Angels, The (1996)', 1.9487179487179487),
#  (tensor(-0.3017), 'Home Alone 3 (1997)', 1.894736842105263),
#  (tensor(-0.2848),
#   'Children of the Corn: The Gathering (1996)',
#   1.3157894736842106),
#  (tensor(-0.2601), 'Cable Guy, The (1996)', 2.339622641509434),
#  (tensor(-0.2564), 'Barb Wire (1996)', 1.9333333333333333),
#  (tensor(-0.2455), 'Grease 2 (1982)', 2.0),
#  (tensor(-0.2435), 'Flintstones, The (1994)', 2.064516129032258),
#  (tensor(-0.2433), 'Airheads (1994)', 2.34375),
#  (tensor(-0.2365), "McHale's Navy (1997)", 2.1884057971014492),
#  (tensor(-0.2320),
#   'Lawnmower Man 2: Beyond Cyberspace (1996)',
#   1.7142857142857142),
#  (tensor(-0.2238), 'Thinner (1996)', 2.4489795918367347),
#  (tensor(-0.2212), 'Beautician and the Beast, The (1997)', 2.313953488372093),
#  (tensor(-0.2206), 'Mortal Kombat: Annihilation (1997)', 1.9534883720930232),
#  (tensor(-0.2071), 'Jungle2Jungle (1997)', 2.4393939393939394),
#  (tensor(-0.1988),
#   'Tales from the Crypt Presents: Bordello of Blood (1996)',
#   2.6363636363636362)]

# %% [markdown]
# Or the ones with the best bias:

# %%
sorted(movie_ratings, key=lambda o: o[0], reverse=True)[:15]
# Out:
# [(tensor(0.5862), 'Titanic (1997)', 4.2457142857142856),
#  (tensor(0.5646), 'Shawshank Redemption, The (1994)', 4.445229681978798),
#  (tensor(0.5595), 'Good Will Hunting (1997)', 4.262626262626263),
#  (tensor(0.5442), 'Star Wars (1977)', 4.3584905660377355),
#  (tensor(0.5214), 'As Good As It Gets (1997)', 4.196428571428571),
#  (tensor(0.5189), "Schindler's List (1993)", 4.466442953020135),
#  (tensor(0.5081), 'L.A. Confidential (1997)', 4.161616161616162),
#  (tensor(0.5052), 'Rear Window (1954)', 4.3875598086124405),
#  (tensor(0.5040), 'Silence of the Lambs, The (1991)', 4.28974358974359),
#  (tensor(0.4965), 'Usual Suspects, The (1995)', 4.385767790262173),
#  (tensor(0.4868), 'Close Shave, A (1995)', 4.491071428571429),
#  (tensor(0.4752), 'Casablanca (1942)', 4.45679012345679),
#  (tensor(0.4647), 'Godfather, The (1972)', 4.283292978208232),
#  (tensor(0.4609), 'Wrong Trousers, The (1993)', 4.466101694915254),
#  (tensor(0.4510), 'Full Monty, The (1997)', 3.926984126984127)]

# %% [markdown]
# There is certainly a strong correlation!

# %% [markdown]
# ### Movie weights

# %% [markdown]
# Now let's try to analyze the latent factors our model has learned. We can grab the weights for each movie in `top_movies` the same way as we did for the bias before.

# %%
movie_w = learn.model.weight(top_movies, is_item=True)
movie_w.shape
# Out:
# torch.Size([1000, 50])

# %% [markdown]
# Let's try a PCA to reduce the dimensions and see if we can see what the model learned:

# %%
movie_pca = movie_w.pca(3)
movie_pca.shape
# Out:
# torch.Size([1000, 3])

# %%
fac0,fac1,fac2 = movie_pca.t()
movie_comp = [(f, i) for f,i in zip(fac0, top_movies)]

# %% [markdown]
# Here are the highest score on the first dimension:

# %%
sorted(movie_comp, key=itemgetter(0), reverse=True)[:10]
# Out:
# [(tensor(1.2921), 'Free Willy 3: The Rescue (1997)'),
#  (tensor(1.2466), 'Bio-Dome (1996)'),
#  (tensor(1.2047), 'Home Alone 3 (1997)'),
#  (tensor(1.2017), "McHale's Navy (1997)"),
#  (tensor(1.1675), 'D3: The Mighty Ducks (1996)'),
#  (tensor(1.0894), 'Sliver (1993)'),
#  (tensor(1.0866), 'Batman & Robin (1997)'),
#  (tensor(1.0597), 'Leave It to Beaver (1997)'),
#  (tensor(1.0435), 'Children of the Corn: The Gathering (1996)'),
#  (tensor(1.0248), 'Jungle2Jungle (1997)')]

# %% [markdown]
# And the worst:

# %%
sorted(movie_comp, key=itemgetter(0))[:10]
# Out:
# [(tensor(-1.1016), 'Chinatown (1974)'),
#  (tensor(-1.0587),
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)'),
#  (tensor(-1.0530), 'Casablanca (1942)'),
#  (tensor(-1.0253), 'Close Shave, A (1995)'),
#  (tensor(-1.0186), 'Godfather, The (1972)'),
#  (tensor(-1.0172), 'Secrets & Lies (1996)'),
#  (tensor(-0.9930), 'Shall We Dance? (1996)'),
#  (tensor(-0.9857), 'Some Folks Call It a Sling Blade (1993)'),
#  (tensor(-0.9856), 'Third Man, The (1949)'),
#  (tensor(-0.9840), 'North by Northwest (1959)')]

# %% [markdown]
# Same thing for our second dimension:

# %%
movie_comp = [(f, i) for f,i in zip(fac1, top_movies)]

# %%
sorted(movie_comp, key=itemgetter(0), reverse=True)[:10]
# Out:
# [(tensor(1.2142), 'Raiders of the Lost Ark (1981)'),
#  (tensor(1.1549), 'Braveheart (1995)'),
#  (tensor(1.0442), 'Titanic (1997)'),
#  (tensor(0.8977), 'Back to the Future (1985)'),
#  (tensor(0.8729), 'Independence Day (ID4) (1996)'),
#  (tensor(0.8567), "Mr. Holland's Opus (1995)"),
#  (tensor(0.8545), 'Fugitive, The (1993)'),
#  (tensor(0.8511), "It's a Wonderful Life (1946)"),
#  (tensor(0.8370), 'Forrest Gump (1994)'),
#  (tensor(0.8181), 'Field of Dreams (1989)')]

# %%
sorted(movie_comp, key=itemgetter(0))[:10]
# Out:
# [(tensor(-0.9124), 'Brazil (1985)'),
#  (tensor(-0.9022), 'Keys to Tulsa (1997)'),
#  (tensor(-0.8941), 'Showgirls (1995)'),
#  (tensor(-0.8365), 'Sweet Hereafter, The (1997)'),
#  (tensor(-0.8273), 'Ready to Wear (Pret-A-Porter) (1994)'),
#  (tensor(-0.8268), 'Serial Mom (1994)'),
#  (tensor(-0.8260), 'Clockwork Orange, A (1971)'),
#  (tensor(-0.7990), 'Trainspotting (1996)'),
#  (tensor(-0.7929), 'Stuart Saves His Family (1995)'),
#  (tensor(-0.7678), 'To Die For (1995)')]

# %% [markdown]
# And we can even plot the movies according to their scores on those dimensions:

# %%
idxs = np.random.choice(len(top_movies), 50, replace=False)
idxs = list(range(50))
X = fac0[idxs]
Y = fac2[idxs]
plt.figure(figsize=(15,15))
plt.scatter(X, Y)
for i, x, y in zip(top_movies[idxs], X, Y):
    plt.text(x,y,i, color=np.random.rand(3)*0.7, fontsize=11)
plt.show()

# %% [markdown]
# # Exercise 2
#
# ## Play around with different collaborative filtering model parameters such as n_factors and other parameters.
# ## Identify if any such parameters have impact on the speed of convergence or the performance on the model

# %%
# !pip install scikit-surprise
from surprise import Dataset
from surprise.model_selection import cross_validate
from surprise.prediction_algorithms import SVD

# Load the dataset (you can replace 'ml-100k' with any other dataset supported by Surprise)
data = Dataset.load_builtin('ml-100k')

# Define a parameter grid to experiment with
param_grid = {'n_factors': [50, 100, 150],
              'reg_all': [0.01, 0.02, 0.03],
              'lr_all': [0.005, 0.01, 0.015],
              'n_epochs': [10, 20, 30]}

# Iterate over parameter combinations
for n_factors in param_grid['n_factors']:
    for reg_all in param_grid['reg_all']:
        for lr_all in param_grid['lr_all']:
            for n_epochs in param_grid['n_epochs']:
                # Define the model with current parameters
                model = SVD(n_factors=n_factors, reg_all=reg_all, lr_all=lr_all, n_epochs=n_epochs)

                # Perform cross-validation
                cv_results = cross_validate(model, data, measures=['RMSE'], cv=5, verbose=True)

                # Extract and print the mean RMSE
                mean_rmse = cv_results['test_rmse'].mean()
                print(f"Parameters: n_factors={n_factors}, reg_all={reg_all}, lr_all={lr_all}, n_epochs={n_epochs}")
                print(f"Mean RMSE: {mean_rmse}")
# Out:
# Collecting scikit-surprise
#   Downloading scikit-surprise-1.1.3.tar.gz (771 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 8.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.11.4)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3163007 sha256=ac5ee0b8ef3b88878087370bd7c4682cd5297d9a3ef36d54536dff103a9da5d1
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.3
# Dataset ml-100k could not be found. Do you want to download it? [Y/n] Y
# Trying to download dataset from https://files.grouplens.org/datasets/movielens/ml-100k.zip...
# Done! Dataset ml-100k has been saved to /root/.surprise_data/ml-100k
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9461  0.9496  0.9451  0.9465  0.9442  0.9463  0.0018
# Fit time          0.52    0.59    0.49    0.35    0.34    0.46    0.10
# Test time         0.17    0.17    0.37    0.17    0.10    0.19    0.09
# Parameters: n_factors=50, reg_all=0.01, lr_all=0.005, n_epochs=10
# Mean RMSE: 0.9462961661136639
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9432  0.9413  0.9382  0.9261  0.9386  0.9375  0.0060
# Fit time          0.63    0.77    0.65    0.62    0.60    0.65    0.06
# Test time         0.09    0.27    0.10    0.10    0.13    0.14    0.07
# Parameters: n_factors=50, reg_all=0.01, lr_all=0.005, n_epochs=20
# Mean RMSE: 0.9374988328450042
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9570  0.9503  0.9502  0.9524  0.9470  0.9514  0.0033
# Fit time          0.91    0.94    1.00    1.59    0.92    1.07    0.26
# Test time         0.10    0.26    0.16    0.17    0.10    0.16    0.06
# Parameters: n_factors=50, reg_all=0.01, lr_all=0.005, n_epochs=30
# Mean RMSE: 0.9513851260095951
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9370  0.9398  0.9353  0.9395  0.9392  0.9381  0.0017
# Fit time          0.40    0.47    0.47    0.47    0.47    0.45    0.03
# Test time         0.29    0.10    0.12    0.10    0.11    0.14    0.07
# Parameters: n_factors=50, reg_all=0.01, lr_all=0.01, n_epochs=10
# Mean RMSE: 0.9381474015154131
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9766  0.9606  0.9690  0.9885  0.9767  0.9743  0.0093
# Fit time          0.88    0.77    0.77    0.72    0.91    0.81    0.07
# Test time         0.27    0.10    0.16    0.21    0.17    0.18    0.06
# Parameters: n_factors=50, reg_all=0.01, lr_all=0.01, n_epochs=20
# Mean RMSE: 0.9742732876034452
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0139  1.0165  1.0168  1.0170  1.0205  1.0169  0.0021
# Fit time          1.44    0.97    1.17    1.03    0.94    1.11    0.18
# Test time         0.26    0.09    0.10    0.12    0.26    0.17    0.08
# Parameters: n_factors=50, reg_all=0.01, lr_all=0.01, n_epochs=30
# Mean RMSE: 1.0169189728852799
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9571  0.9429  0.9533  0.9418  0.9537  0.9498  0.0062
# Fit time          0.35    0.33    0.34    0.35    0.39    0.35    0.02
# Test time         0.10    0.09    0.10    0.10    0.28    0.13    0.07
# Parameters: n_factors=50, reg_all=0.01, lr_all=0.015, n_epochs=10
# Mean RMSE: 0.9497659824389473
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0167  1.0183  1.0134  1.0118  1.0101  1.0141  0.0030
# Fit time          0.87    1.29    0.81    0.70    0.65    0.86    0.22
# Test time         0.17    0.17    0.10    0.10    0.10    0.13    0.04
# Parameters: n_factors=50, reg_all=0.01, lr_all=0.015, n_epochs=20
# Mean RMSE: 1.0140648304916204
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0605  1.0338  1.0546  1.0516  1.0519  1.0505  0.0089
# Fit time          0.96    0.90    1.12    1.30    1.13    1.08    0.14
# Test time         0.10    0.10    0.12    0.29    0.09    0.14    0.07
# Parameters: n_factors=50, reg_all=0.01, lr_all=0.015, n_epochs=30
# Mean RMSE: 1.0505050389651105
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9462  0.9475  0.9477  0.9475  0.9424  0.9463  0.0020
# Fit time          0.54    0.57    0.51    0.33    0.35    0.46    0.10
# Test time         0.16    0.17    0.10    0.33    0.10    0.17    0.08
# Parameters: n_factors=50, reg_all=0.02, lr_all=0.005, n_epochs=10
# Mean RMSE: 0.9462525661606239
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9353  0.9292  0.9366  0.9324  0.9330  0.9333  0.0026
# Fit time          0.64    0.64    0.62    0.66    0.65    0.65    0.01
# Test time         0.11    0.11    0.26    0.09    0.11    0.14    0.06
# Parameters: n_factors=50, reg_all=0.02, lr_all=0.005, n_epochs=20
# Mean RMSE: 0.9333059004977196
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9328  0.9406  0.9451  0.9344  0.9352  0.9376  0.0046
# Fit time          0.91    0.91    0.94    1.61    0.93    1.06    0.27
# Test time         0.11    0.10    0.32    0.17    0.16    0.17    0.08
# Parameters: n_factors=50, reg_all=0.02, lr_all=0.005, n_epochs=30
# Mean RMSE: 0.9376165737967828
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9387  0.9359  0.9303  0.9245  0.9396  0.9338  0.0057
# Fit time          0.31    0.34    0.37    0.33    0.41    0.35    0.04
# Test time         0.12    0.26    0.09    0.10    0.10    0.13    0.06
# Parameters: n_factors=50, reg_all=0.02, lr_all=0.01, n_epochs=10
# Mean RMSE: 0.9337787353253659
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9560  0.9594  0.9512  0.9544  0.9477  0.9537  0.0040
# Fit time          0.66    0.63    0.65    0.64    0.65    0.65    0.01
# Test time         0.10    0.28    0.10    0.10    0.14    0.14    0.07
# Parameters: n_factors=50, reg_all=0.02, lr_all=0.01, n_epochs=20
# Mean RMSE: 0.9537443547130243
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9840  0.9700  0.9913  0.9795  0.9845  0.9819  0.0070
# Fit time          1.01    1.57    0.97    1.13    1.20    1.18    0.21
# Test time         0.14    0.34    0.09    0.11    0.10    0.16    0.09
# Parameters: n_factors=50, reg_all=0.02, lr_all=0.01, n_epochs=30
# Mean RMSE: 0.9818628744759245
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9354  0.9421  0.9352  0.9350  0.9394  0.9374  0.0029
# Fit time          0.44    0.47    0.46    0.46    0.43    0.45    0.02
# Test time         0.31    0.15    0.11    0.12    0.13    0.16    0.07
# Parameters: n_factors=50, reg_all=0.02, lr_all=0.015, n_epochs=10
# Mean RMSE: 0.9374082099454121
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9900  0.9772  0.9822  0.9824  0.9786  0.9821  0.0044
# Fit time          0.84    0.90    1.28    0.68    0.72    0.88    0.21
# Test time         0.27    0.17    0.18    0.11    0.28    0.20    0.06
# Parameters: n_factors=50, reg_all=0.02, lr_all=0.015, n_epochs=20
# Mean RMSE: 0.9820972328172408
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0022  1.0015  1.0145  1.0071  1.0019  1.0055  0.0050
# Fit time          1.21    1.19    1.27    1.00    1.01    1.14    0.11
# Test time         0.18    0.11    0.12    0.10    0.26    0.15    0.06
# Parameters: n_factors=50, reg_all=0.02, lr_all=0.015, n_epochs=30
# Mean RMSE: 1.0054523867076581
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9540  0.9412  0.9444  0.9431  0.9454  0.9456  0.0044
# Fit time          0.36    0.56    0.61    0.51    0.35    0.48    0.10
# Test time         0.09    0.17    0.16    0.14    0.26    0.17    0.06
# Parameters: n_factors=50, reg_all=0.03, lr_all=0.005, n_epochs=10
# Mean RMSE: 0.9455999012379257
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9321  0.9381  0.9334  0.9308  0.9319  0.9332  0.0025
# Fit time          0.66    0.67    0.87    0.71    0.88    0.76    0.10
# Test time         0.09    0.10    0.10    0.10    0.28    0.13    0.07
# Parameters: n_factors=50, reg_all=0.03, lr_all=0.005, n_epochs=20
# Mean RMSE: 0.9332440625142835
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9270  0.9333  0.9304  0.9243  0.9254  0.9281  0.0033
# Fit time          1.30    1.27    1.57    1.35    0.91    1.28    0.21
# Test time         0.10    0.12    0.18    0.10    0.28    0.15    0.07
# Parameters: n_factors=50, reg_all=0.03, lr_all=0.005, n_epochs=30
# Mean RMSE: 0.9281023941314466
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9287  0.9507  0.9319  0.9292  0.9272  0.9335  0.0087
# Fit time          0.47    0.40    0.39    0.38    0.45    0.42    0.04
# Test time         0.10    0.10    0.10    0.10    0.29    0.14    0.08
# Parameters: n_factors=50, reg_all=0.03, lr_all=0.01, n_epochs=10
# Mean RMSE: 0.933518049957837
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9365  0.9418  0.9382  0.9344  0.9355  0.9373  0.0026
# Fit time          0.71    0.89    0.83    0.79    1.06    0.85    0.12
# Test time         0.10    0.10    0.10    0.10    0.16    0.11    0.02
# Parameters: n_factors=50, reg_all=0.03, lr_all=0.01, n_epochs=20
# Mean RMSE: 0.9372642611185033
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9581  0.9590  0.9577  0.9597  0.9601  0.9589  0.0009
# Fit time          1.09    0.95    0.92    0.89    1.03    0.98    0.07
# Test time         0.10    0.09    0.10    0.32    0.09    0.14    0.09
# Parameters: n_factors=50, reg_all=0.03, lr_all=0.01, n_epochs=30
# Mean RMSE: 0.9589239499408011
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9349  0.9266  0.9296  0.9210  0.9262  0.9277  0.0045
# Fit time          0.33    0.35    0.36    0.35    0.33    0.35    0.01
# Test time         0.10    0.10    0.26    0.10    0.11    0.13    0.06
# Parameters: n_factors=50, reg_all=0.03, lr_all=0.015, n_epochs=10
# Mean RMSE: 0.9276681405742485
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9589  0.9572  0.9703  0.9587  0.9535  0.9597  0.0056
# Fit time          0.69    1.04    1.06    0.65    0.64    0.82    0.19
# Test time         0.10    0.16    0.26    0.10    0.11    0.15    0.06
# Parameters: n_factors=50, reg_all=0.03, lr_all=0.015, n_epochs=20
# Mean RMSE: 0.959703552131885
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9875  0.9794  0.9709  0.9820  0.9785  0.9797  0.0054
# Fit time          0.96    0.96    1.11    1.26    1.29    1.12    0.14
# Test time         0.09    0.10    0.34    0.10    0.11    0.15    0.09
# Parameters: n_factors=50, reg_all=0.03, lr_all=0.015, n_epochs=30
# Mean RMSE: 0.9796781926076502
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9462  0.9437  0.9491  0.9496  0.9505  0.9478  0.0025
# Fit time          0.67    0.93    0.62    0.59    0.54    0.67    0.14
# Test time         0.19    0.17    0.10    0.10    0.10    0.13    0.04
# Parameters: n_factors=100, reg_all=0.01, lr_all=0.005, n_epochs=10
# Mean RMSE: 0.9478302579995557
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9472  0.9395  0.9418  0.9419  0.9416  0.9424  0.0026
# Fit time          0.97    0.95    1.08    1.19    1.24    1.09    0.11
# Test time         0.09    0.30    0.12    0.10    0.12    0.15    0.08
# Parameters: n_factors=100, reg_all=0.01, lr_all=0.005, n_epochs=20
# Mean RMSE: 0.9423940041181892
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9602  0.9679  0.9580  0.9591  0.9587  0.9608  0.0036
# Fit time          2.24    1.44    1.48    1.50    1.48    1.63    0.31
# Test time         0.40    0.20    0.10    0.11    0.17    0.19    0.11
# Parameters: n_factors=100, reg_all=0.01, lr_all=0.005, n_epochs=30
# Mean RMSE: 0.960776839343529
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9404  0.9435  0.9385  0.9458  0.9393  0.9415  0.0028
# Fit time          0.63    0.65    0.65    0.92    0.92    0.75    0.14
# Test time         0.33    0.11    0.10    0.17    0.10    0.16    0.09
# Parameters: n_factors=100, reg_all=0.01, lr_all=0.01, n_epochs=10
# Mean RMSE: 0.9415102001964705
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9696  0.9799  0.9781  0.9733  0.9819  0.9766  0.0045
# Fit time          0.97    1.01    1.05    0.97    1.14    1.03    0.07
# Test time         0.10    0.10    0.10    0.10    0.29    0.14    0.08
# Parameters: n_factors=100, reg_all=0.01, lr_all=0.01, n_epochs=20
# Mean RMSE: 0.9765712027993392
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0017  1.0020  1.0071  0.9980  1.0129  1.0043  0.0052
# Fit time          1.56    1.56    1.97    1.42    1.43    1.59    0.20
# Test time         0.10    0.17    0.10    0.35    0.10    0.16    0.10
# Parameters: n_factors=100, reg_all=0.01, lr_all=0.01, n_epochs=30
# Mean RMSE: 1.0043225895037156
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9556  0.9554  0.9569  0.9622  0.9662  0.9593  0.0043
# Fit time          0.54    0.60    0.52    0.50    0.52    0.54    0.03
# Test time         0.10    0.11    0.10    0.32    0.09    0.14    0.09
# Parameters: n_factors=100, reg_all=0.01, lr_all=0.015, n_epochs=10
# Mean RMSE: 0.9592739125553378
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0015  1.0090  0.9974  0.9977  1.0016  1.0014  0.0042
# Fit time          1.04    1.48    1.38    1.24    1.21    1.27    0.15
# Test time         0.11    0.16    0.10    0.32    0.10    0.16    0.08
# Parameters: n_factors=100, reg_all=0.01, lr_all=0.015, n_epochs=20
# Mean RMSE: 1.0014484933527856
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0162  1.0342  1.0165  1.0159  1.0147  1.0195  0.0074
# Fit time          1.80    1.74    1.84    2.07    1.42    1.77    0.21
# Test time         0.10    0.12    0.38    0.10    0.10    0.16    0.11
# Parameters: n_factors=100, reg_all=0.01, lr_all=0.015, n_epochs=30
# Mean RMSE: 1.019529138810385
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9489  0.9486  0.9486  0.9499  0.9460  0.9484  0.0013
# Fit time          0.55    0.64    0.62    0.55    0.57    0.59    0.04
# Test time         0.19    0.18    0.28    0.10    0.19    0.19    0.06
# Parameters: n_factors=100, reg_all=0.02, lr_all=0.005, n_epochs=10
# Mean RMSE: 0.9484027209315734
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9460  0.9410  0.9363  0.9286  0.9315  0.9367  0.0063
# Fit time          0.97    0.99    1.41    1.21    1.17    1.15    0.16
# Test time         0.10    0.10    0.37    0.17    0.10    0.17    0.11
# Parameters: n_factors=100, reg_all=0.02, lr_all=0.005, n_epochs=20
# Mean RMSE: 0.9366911767658113
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9411  0.9439  0.9428  0.9489  0.9372  0.9428  0.0038
# Fit time          1.81    1.64    1.50    1.40    2.25    1.72    0.30
# Test time         0.10    0.11    0.37    0.12    0.11    0.16    0.10
# Parameters: n_factors=100, reg_all=0.02, lr_all=0.005, n_epochs=30
# Mean RMSE: 0.9427686354001754
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9362  0.9379  0.9328  0.9283  0.9455  0.9362  0.0057
# Fit time          0.61    0.60    0.61    0.54    0.57    0.59    0.03
# Test time         0.11    0.28    0.10    0.10    0.15    0.15    0.07
# Parameters: n_factors=100, reg_all=0.02, lr_all=0.01, n_epochs=10
# Mean RMSE: 0.9361599000455334
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9519  0.9625  0.9477  0.9564  0.9514  0.9540  0.0051
# Fit time          0.98    0.97    1.00    0.97    1.60    1.11    0.25
# Test time         0.11    0.25    0.11    0.10    0.17    0.15    0.06
# Parameters: n_factors=100, reg_all=0.02, lr_all=0.01, n_epochs=20
# Mean RMSE: 0.9539713274133174
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9715  0.9711  0.9574  0.9706  0.9729  0.9687  0.0057
# Fit time          1.43    1.45    1.42    1.51    1.44    1.45    0.03
# Test time         0.26    0.10    0.11    0.11    0.10    0.13    0.06
# Parameters: n_factors=100, reg_all=0.02, lr_all=0.01, n_epochs=30
# Mean RMSE: 0.9686941456493763
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9483  0.9358  0.9453  0.9374  0.9387  0.9411  0.0048
# Fit time          0.54    0.56    0.84    0.71    0.56    0.64    0.12
# Test time         0.26    0.17    0.16    0.10    0.13    0.16    0.05
# Parameters: n_factors=100, reg_all=0.02, lr_all=0.015, n_epochs=10
# Mean RMSE: 0.941091092568006
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9722  0.9692  0.9681  0.9674  0.9758  0.9705  0.0031
# Fit time          1.22    1.24    1.15    1.10    1.11    1.17    0.06
# Test time         0.37    0.11    0.21    0.11    0.30    0.22    0.10
# Parameters: n_factors=100, reg_all=0.02, lr_all=0.015, n_epochs=20
# Mean RMSE: 0.9705430667793516
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9829  0.9761  0.9801  0.9835  0.9808  0.9807  0.0026
# Fit time          1.74    2.12    1.69    1.51    1.45    1.70    0.24
# Test time         0.17    0.11    0.11    0.11    0.29    0.16    0.07
# Parameters: n_factors=100, reg_all=0.02, lr_all=0.015, n_epochs=30
# Mean RMSE: 0.9806956280589197
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9506  0.9412  0.9433  0.9494  0.9499  0.9469  0.0039
# Fit time          0.52    0.53    0.50    0.63    0.95    0.63    0.17
# Test time         0.12    0.10    0.11    0.34    0.18    0.17    0.09
# Parameters: n_factors=100, reg_all=0.03, lr_all=0.005, n_epochs=10
# Mean RMSE: 0.9468919046304538
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9230  0.9388  0.9362  0.9256  0.9402  0.9327  0.0071
# Fit time          1.24    1.22    1.07    1.06    1.05    1.13    0.08
# Test time         0.10    0.18    0.11    0.28    0.10    0.15    0.07
# Parameters: n_factors=100, reg_all=0.03, lr_all=0.005, n_epochs=20
# Mean RMSE: 0.9327413972753277
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9335  0.9356  0.9277  0.9351  0.9295  0.9323  0.0031
# Fit time          1.62    1.78    1.93    1.46    1.43    1.64    0.19
# Test time         0.11    0.17    0.10    0.27    0.18    0.17    0.06
# Parameters: n_factors=100, reg_all=0.03, lr_all=0.005, n_epochs=30
# Mean RMSE: 0.9322698182461433
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9316  0.9379  0.9371  0.9263  0.9284  0.9323  0.0046
# Fit time          0.49    0.53    0.51    0.50    0.52    0.51    0.01
# Test time         0.10    0.10    0.27    0.10    0.10    0.13    0.07
# Parameters: n_factors=100, reg_all=0.03, lr_all=0.01, n_epochs=10
# Mean RMSE: 0.9322765777229189
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9329  0.9475  0.9386  0.9328  0.9467  0.9397  0.0064
# Fit time          1.00    1.42    1.24    0.96    0.95    1.11    0.19
# Test time         0.10    0.17    0.27    0.10    0.21    0.17    0.06
# Parameters: n_factors=100, reg_all=0.03, lr_all=0.01, n_epochs=20
# Mean RMSE: 0.9397137278327182
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9512  0.9514  0.9462  0.9469  0.9473  0.9486  0.0023
# Fit time          1.48    1.47    1.55    1.66    2.16    1.67    0.25
# Test time         0.10    0.10    0.28    0.18    0.13    0.16    0.07
# Parameters: n_factors=100, reg_all=0.03, lr_all=0.01, n_epochs=30
# Mean RMSE: 0.9486053161753178
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9338  0.9318  0.9323  0.9305  0.9365  0.9330  0.0020
# Fit time          0.61    0.64    0.65    0.63    0.60    0.63    0.02
# Test time         0.18    0.29    0.17    0.11    0.10    0.17    0.07
# Parameters: n_factors=100, reg_all=0.03, lr_all=0.015, n_epochs=10
# Mean RMSE: 0.9329796229655087
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9513  0.9428  0.9519  0.9485  0.9525  0.9494  0.0036
# Fit time          1.20    1.07    1.00    1.55    1.24    1.21    0.19
# Test time         0.10    0.09    0.10    0.17    0.11    0.11    0.03
# Parameters: n_factors=100, reg_all=0.03, lr_all=0.015, n_epochs=20
# Mean RMSE: 0.9493962056146337
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9553  0.9542  0.9555  0.9517  0.9481  0.9530  0.0028
# Fit time          1.75    1.62    1.44    1.39    1.59    1.56    0.13
# Test time         0.28    0.11    0.10    0.10    0.16    0.15    0.07
# Parameters: n_factors=100, reg_all=0.03, lr_all=0.015, n_epochs=30
# Mean RMSE: 0.9529580176837869
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9516  0.9569  0.9419  0.9494  0.9535  0.9507  0.0051
# Fit time          1.06    0.80    0.85    0.82    0.81    0.87    0.10
# Test time         0.15    0.12    0.11    0.12    0.31    0.16    0.08
# Parameters: n_factors=150, reg_all=0.01, lr_all=0.005, n_epochs=10
# Mean RMSE: 0.9506712725840705
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9463  0.9479  0.9472  0.9501  0.9453  0.9474  0.0016
# Fit time          1.57    1.46    1.40    2.15    1.50    1.61    0.27
# Test time         0.12    0.11    0.15    0.28    0.11    0.16    0.07
# Parameters: n_factors=150, reg_all=0.01, lr_all=0.005, n_epochs=20
# Mean RMSE: 0.9473756008180241
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9579  0.9608  0.9702  0.9554  0.9654  0.9619  0.0053
# Fit time          2.15    1.96    1.93    2.45    1.92    2.08    0.20
# Test time         0.11    0.12    0.11    0.40    0.11    0.17    0.12
# Parameters: n_factors=150, reg_all=0.01, lr_all=0.005, n_epochs=30
# Mean RMSE: 0.9619403363668113
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9548  0.9405  0.9397  0.9537  0.9484  0.9474  0.0064
# Fit time          0.68    0.67    0.66    0.67    0.64    0.66    0.01
# Test time         0.11    0.12    0.11    0.26    0.11    0.14    0.06
# Parameters: n_factors=150, reg_all=0.01, lr_all=0.01, n_epochs=10
# Mean RMSE: 0.9474095068827285
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9771  0.9772  0.9756  0.9753  0.9687  0.9748  0.0032
# Fit time          1.46    1.53    2.01    1.54    1.47    1.60    0.21
# Test time         0.14    0.17    0.30    0.16    0.12    0.18    0.06
# Parameters: n_factors=150, reg_all=0.01, lr_all=0.01, n_epochs=20
# Mean RMSE: 0.9747761453167618
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9881  0.9836  0.9887  0.9880  0.9971  0.9891  0.0044
# Fit time          2.07    1.91    2.86    2.09    1.92    2.17    0.35
# Test time         0.11    0.12    0.39    0.11    0.11    0.17    0.11
# Parameters: n_factors=150, reg_all=0.01, lr_all=0.01, n_epochs=30
# Mean RMSE: 0.9890769833741555
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9540  0.9600  0.9674  0.9592  0.9553  0.9591  0.0047
# Fit time          0.69    0.68    0.69    0.71    0.70    0.69    0.01
# Test time         0.10    0.10    0.27    0.11    0.10    0.14    0.07
# Parameters: n_factors=150, reg_all=0.01, lr_all=0.015, n_epochs=10
# Mean RMSE: 0.9591479743818407
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9862  0.9939  0.9846  0.9828  0.9920  0.9879  0.0043
# Fit time          1.95    1.64    1.46    1.41    1.32    1.56    0.22
# Test time         0.18    0.29    0.12    0.13    0.11    0.17    0.06
# Parameters: n_factors=150, reg_all=0.01, lr_all=0.015, n_epochs=20
# Mean RMSE: 0.9879059609812039
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9915  0.9904  0.9911  0.9917  0.9894  0.9908  0.0008
# Fit time          1.89    2.60    2.08    1.85    1.92    2.07    0.28
# Test time         0.11    0.41    0.11    0.10    0.11    0.17    0.12
# Parameters: n_factors=150, reg_all=0.01, lr_all=0.015, n_epochs=30
# Mean RMSE: 0.9908155189045775
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9436  0.9445  0.9486  0.9494  0.9559  0.9484  0.0044
# Fit time          0.66    0.75    0.80    1.07    1.09    0.87    0.17
# Test time         0.11    0.29    0.11    0.17    0.11    0.16    0.07
# Parameters: n_factors=150, reg_all=0.02, lr_all=0.005, n_epochs=10
# Mean RMSE: 0.9484098309536497
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9402  0.9431  0.9288  0.9463  0.9373  0.9391  0.0060
# Fit time          1.41    1.24    1.29    1.31    1.48    1.35    0.09
# Test time         0.10    0.25    0.11    0.13    0.12    0.14    0.06
# Parameters: n_factors=150, reg_all=0.02, lr_all=0.005, n_epochs=20
# Mean RMSE: 0.9391281978553643
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9425  0.9432  0.9513  0.9411  0.9422  0.9441  0.0037
# Fit time          2.71    2.37    2.28    2.17    1.97    2.30    0.24
# Test time         0.42    0.11    0.11    0.10    0.11    0.17    0.12
# Parameters: n_factors=150, reg_all=0.02, lr_all=0.005, n_epochs=30
# Mean RMSE: 0.9440734002832443
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9412  0.9368  0.9412  0.9456  0.9361  0.9402  0.0035
# Fit time          0.98    1.15    0.69    0.76    0.69    0.85    0.18
# Test time         0.18    0.11    0.11    0.11    0.31    0.17    0.08
# Parameters: n_factors=150, reg_all=0.02, lr_all=0.01, n_epochs=10
# Mean RMSE: 0.9401810768388927
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9528  0.9535  0.9569  0.9514  0.9529  0.9535  0.0018
# Fit time          1.37    1.32    1.31    1.31    1.91    1.44    0.23
# Test time         0.12    0.11    0.11    0.11    0.37    0.16    0.11
# Parameters: n_factors=150, reg_all=0.02, lr_all=0.01, n_epochs=20
# Mean RMSE: 0.953513744434144
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9603  0.9633  0.9619  0.9517  0.9581  0.9591  0.0041
# Fit time          2.09    2.23    2.08    1.88    2.97    2.25    0.38
# Test time         0.12    0.11    0.21    0.38    0.12    0.19    0.10
# Parameters: n_factors=150, reg_all=0.02, lr_all=0.01, n_epochs=30
# Mean RMSE: 0.9590612395783993
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9449  0.9448  0.9504  0.9427  0.9403  0.9446  0.0033
# Fit time          0.77    0.72    0.72    0.67    0.67    0.71    0.04
# Test time         0.12    0.11    0.11    0.27    0.12    0.14    0.06
# Parameters: n_factors=150, reg_all=0.02, lr_all=0.015, n_epochs=10
# Mean RMSE: 0.9446388676847957
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9624  0.9575  0.9587  0.9578  0.9689  0.9611  0.0043
# Fit time          1.28    1.28    1.30    1.87    1.29    1.40    0.23
# Test time         0.10    0.11    0.16    0.26    0.11    0.15    0.06
# Parameters: n_factors=150, reg_all=0.02, lr_all=0.015, n_epochs=20
# Mean RMSE: 0.961067018605336
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9636  0.9583  0.9580  0.9592  0.9619  0.9602  0.0022
# Fit time          1.90    1.92    1.89    2.34    2.34    2.08    0.21
# Test time         0.10    0.11    0.26    0.17    0.20    0.17    0.06
# Parameters: n_factors=150, reg_all=0.02, lr_all=0.015, n_epochs=30
# Mean RMSE: 0.9602125875676041
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9535  0.9526  0.9403  0.9468  0.9523  0.9491  0.0050
# Fit time          0.68    0.78    0.76    0.81    0.80    0.77    0.04
# Test time         0.19    0.13    0.30    0.12    0.11    0.17    0.07
# Parameters: n_factors=150, reg_all=0.03, lr_all=0.005, n_epochs=10
# Mean RMSE: 0.9491065046195712
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9342  0.9265  0.9382  0.9351  0.9304  0.9329  0.0040
# Fit time          1.38    1.76    1.79    1.43    1.43    1.56    0.18
# Test time         0.11    0.17    0.28    0.20    0.19    0.19    0.06
# Parameters: n_factors=150, reg_all=0.03, lr_all=0.005, n_epochs=20
# Mean RMSE: 0.9329011776802061
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9385  0.9304  0.9318  0.9228  0.9385  0.9324  0.0059
# Fit time          1.89    2.00    2.76    2.17    2.27    2.22    0.30
# Test time         0.10    0.27    0.12    0.12    0.11    0.14    0.06
# Parameters: n_factors=150, reg_all=0.03, lr_all=0.005, n_epochs=30
# Mean RMSE: 0.9324059366902219
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9301  0.9340  0.9355  0.9372  0.9352  0.9344  0.0024
# Fit time          0.81    0.81    0.74    0.74    0.98    0.82    0.09
# Test time         0.11    0.35    0.18    0.15    0.17    0.19    0.08
# Parameters: n_factors=150, reg_all=0.03, lr_all=0.01, n_epochs=10
# Mean RMSE: 0.9343995493283082
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9335  0.9287  0.9353  0.9472  0.9438  0.9377  0.0068
# Fit time          1.83    1.37    1.47    1.56    1.41    1.53    0.16
# Test time         0.11    0.34    0.14    0.15    0.10    0.17    0.09
# Parameters: n_factors=150, reg_all=0.03, lr_all=0.01, n_epochs=20
# Mean RMSE: 0.9376970515477158
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9414  0.9503  0.9454  0.9377  0.9355  0.9421  0.0053
# Fit time          2.01    2.39    1.86    1.89    1.88    2.01    0.20
# Test time         0.36    0.10    0.12    0.23    0.11    0.19    0.10
# Parameters: n_factors=150, reg_all=0.03, lr_all=0.01, n_epochs=30
# Mean RMSE: 0.9420650446447352
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9339  0.9360  0.9359  0.9348  0.9242  0.9330  0.0044
# Fit time          0.65    0.75    1.11    1.12    0.75    0.87    0.20
# Test time         0.12    0.11    0.18    0.13    0.29    0.17    0.06
# Parameters: n_factors=150, reg_all=0.03, lr_all=0.015, n_epochs=10
# Mean RMSE: 0.9329835457681387
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9444  0.9407  0.9357  0.9509  0.9417  0.9427  0.0050
# Fit time          1.52    1.46    1.46    1.43    1.70    1.51    0.10
# Test time         0.12    0.19    0.11    0.28    0.17    0.17    0.06
# Parameters: n_factors=150, reg_all=0.03, lr_all=0.015, n_epochs=20
# Mean RMSE: 0.9426850201050451
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9461  0.9386  0.9399  0.9440  0.9482  0.9433  0.0036
# Fit time          2.63    2.02    1.84    1.86    2.26    2.12    0.29
# Test time         0.10    0.10    0.14    0.27    0.18    0.16    0.06
# Parameters: n_factors=150, reg_all=0.03, lr_all=0.015, n_epochs=30
# Mean RMSE: 0.9433449461629386
